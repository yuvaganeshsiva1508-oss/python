# %% [markdown]
# a = int(input("enter a number :"))
# b = int(input("enter b number :"))
# c = int(input("enter c number :"))
#
#
# if a>b and a>c
#     print ("a is bigger ")
# elif a==b and a==c:
#      print ("b is equal ")
# elif a<b b<c:
#     print ("c is simaller")

# %%
a = int(input("enter a number :"))
b = int(input("enter b number :"))
c = int(input("enter c number :"))


if a>b and a>c:
    print ("a is bigger ")
elif b>a and b>c:
     print ("b is bigger") 
elif c>a and c>b:
    print ("c is bigger")
# Out:
# a is bigger

# %%
a = 1
while a<= row
    b = 1
    while b <= "column":
        print("*", end=" ")
        b += 1
    a += 1
    print()
# Out:
#   Cell In[7], line 2
#     while a<= row
#                  ^
# SyntaxError: expected ':'

# %%
i = 1
while i <= 6:
    print(i, end="")
    i += 1
# Out:
# 123456

# %%
for x in range(5):
    print("*")
