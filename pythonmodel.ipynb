# %%
import re
with open("C:\\Users\\YUVAGANESH.S\\OneDrive\\Desktop\\yuva.txt")as file:
    mydata=file.read()

    mylist = re.findall(r"[Aa][n][d]",mydata)
    print(mylist)
# Out:
# ['and', 'and']

# %%
import re
with open ("C:\\Users\\YUVAGANESH.S\\OneDrive\\Desktop\\yuva.txt
")as myfile:
    mydata = myfile.read()
    mylist = re.findall(r"\d{2}[-\.][-/.]\d{4}",mydata)
    print(mylist)

    for each in mylist:
        print(each)
# Out:
# []

# %%
import re
with open ("C:\\Users\\YtUVAGANESH.S\\OneDrive\\Desktop\\yuva.txt")as myfile:
    mydata = myfile.read()
    mylist = re.findall(r"\d{2}[-\.][-/.]\d{4}",mydata)
    print(mylist)


    for each in mylist:
        print(each)
# Out:
#   Cell In[7], line 2
#     with open ("C:\\Users\\YtUVAGANESH.S\\OneDrive\\Desktop\\yuva."tx)as myfile:
#                ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ## ** split()**

# %%
import re

with open ("C:\\Users\\YUVAGANESH.S\\OneDrive\\Desktop\\yuva.txt")as myfile:
    mydata = myfile . read()

    mylist = re.split(r" ",mydata)

    for each in mylist:
        print(each)
# Out:
# Lorem
# ipsum
# dolor
# sit
# amet,
# consectetur
# adipiscing
# elit.
# Donec
# egestas
# diam
# non
# tellus
# bibendum
# ornare.
# Donec
# a
# sapien
# a
# ante
# suscipit
# mollis.
# Nam
# sodales
# sit
# amet
# mauris
# vel
# mollis.
# Mauris
# ornare
# laoreet
# erat.
# Vivamus
# non
# ultrices
# est.
# Aliquam
# pulvinar
# quam
# quis
# condimentum
# sagittis.
# Sed
# varius
# id
# dui
# eget
# pretium.
# Nunc
# ac
# venenatis
# eros.
# Ut
# dignissim
# dapibus
# tellus
# quis
# sollicitudin.
# Nulla
# dictum
# at
# tortor
# at
# blandit.
# Sed
# vitae
# blandit
# augue.
# Sed
# sagittis
# maximus
# suscipit.
# Donec
# pulvinar
# nunc
# in
# magna
# euismod
# viverra.\[12/05/2323],[14,05,2323]

# %% [markdown]
# ## **sub()

# %%
with open ("C:\\Users\\YUVAGANESH.S\\OneDrive\\Desktop\\yuva.txt")as myfile:
    mydata = myfile.read()

    mylist = re.sub(r"",'\n',mydata)
    print(mylist)
# Out:
# L
# o
# r
# e
# m
#
# i
# p
# s
# u
# m
#
# d
# o
# l
# o
# r
#
# s
# i
# t
#
# a
# m
# e
# t
# ,
#
# c
# o
# n
# s
# e
# c
# t
# e
# t
# u
# r
#
# a
# d
# i
# p
# i
# s
# c
# i
# n
# g
#
# e
# l
# i
# t
# .
#
# D
# o
# n
# e
# c
#
# e
# g
# e
# s
# t
# a
# s
#
# d
# i
# a
# m
#
# n
# o
# n
#
# t
# e
# l
# l
# u
# s
#
# b
# i
# b
# e
# n
# d
# u
# m
#
# o
# r
# n
# a
# r
# e
# .
#
# D
# o
# n
# e
# c
#
# a
#
# s
# a
# p
# i
# e
# n
#
# a
#
# a
# n
# t
# e
#
# s
# u
# s
# c
# i
# p
# i
# t
#
# m
# o
# l
# l
# i
# s
# .
#
# N
# a
# m
#
# s
# o
# d
# a
# l
# e
# s
#
# s
# i
# t
#
# a
# m
# e
# t
#
# m
# a
# u
# r
# i
# s
#
# v
# e
# l
#
# m
# o
# l
# l
# i
# s
# .
#
# M
# a
# u
# r
# i
# s
#
# o
# r
# n
# a
# r
# e
#
# l
# a
# o
# r
# e
# e
# t
#
# e
# r
# a
# t
# .
#
# V
# i
# v
# a
# m
# u
# s
#
# n
# o
# n
#
# u
# l
# t
# r
# i
# c
# e
# s
#
# e
# s
# t
# .
#
# A
# l
# i
# q
# u
# a
# m
#
# p
# u
# l
# v
# i
# n
# a
# r
#
# q
# u
# a
# m
#
# q
# u
# i
# s
#
# c
# o
# n
# d
# i
# m
# ...

# %% [markdown]
# # **search**()
