# %% [markdown]
# # **dictionary function** #

# %%
mydict = {
    "Name" : "yuvaganesh",
    "age"  :  21,
    "city" : "kachipuram",
     500   : 60.0 , 

}

print(mydict,type(mydict) )
print(mydict[500])
mydict["city"]='kovai'
mydict["coures"]="python"
print(mydict)
